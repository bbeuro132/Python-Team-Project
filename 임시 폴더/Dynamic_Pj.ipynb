# %%
# %matplotlib notebook
import csv
import matplotlib.pyplot as plt
import numpy as np
import time




corona_file = open('kr_daily.csv')
kakao_file = open('kakao1.csv')
s = open('Ko2019.csv',encoding = 'cp949')
d = open('Ko2020.csv',encoding = 'cp949')
f = open('Ko2021.csv',encoding = 'cp949')
data2019 = csv.reader(s)
data2020 = csv.reader(d)
data2021 = csv.reader(f)
kakao_data = csv.reader(kakao_file)
corona_data = csv.reader(corona_file)
corona_month=[]
corona_number=[] # 확진자 수
kakao_month=[]
kakao_netflix=[]
kakao_cgv=[]
kakao_corona=[]
month = []
score = []
index =0
temp1 = 0
temp2 = 0
max = 0
maxx = 0

for x in range(4) :
    next(data2019)
for x in range(6) :
    next(data2019)
    next(data2020)
    next(data2021)

next(corona_data)
next(kakao_data)
def plt_dynamic(x, y, ax, color):
    ax.plot(x, y, color)
    fig.canvas.draw()
    
fig, ax = plt.subplots(1,1)    
ax.set_xlim(0,24) ; ax.set_ylim(0,100)


for item in kakao_data: #카카오 데이터 리스트화
    kakao_month.append(item[0][2:4]+'.'+item[0][5:7])
    kakao_netflix.append(int(item[1]))
    kakao_cgv.append(int(item[2]))
    kakao_corona.append(int(item[3]))
    plt_dynamic(kakao_month, kakao_netflix, ax, 'pink')
    plt_dynamic(kakao_month, kakao_cgv, ax, 'blue')
    plt_dynamic(kakao_month, kakao_corona, ax, 'green')
    time.sleep(.2)
# Out:
# <img src="data:image/png;base64,..." width="640">
