# %%
import csv
import matplotlib.pyplot as plt

f = open('kakao.csv',encoding = 'cp949')
data = csv.reader(f)
next(data)
next(data)
cgv = []
corona = []
netflix = []
month = []
for i in data :
    if '' in i :
        continue
    corona.append(int(i[3]))
    cgv.append(int(i[2]))
    netflix.append(int(i[1])) 
    month.append(i[0][2:7])
    
print(month)    
plt.figure(figsize = (25,5))
plt.plot(month, corona)
plt.plot(month, netflix)
plt.plot(month, cgv)
plt.xticks(color='white', fontsize =14)
x.label(년-월)
plt.legend(['corona', 'netflix', 'cgv'])
# Out:
# ['19-04', '19-05', '19-06', '19-07', '19-08', '19-09', '19-10', '19-11', '19-12', '20-01', '20-02', '20-03', '20-04', '20-05', '20-06', '20-07', '20-08', '20-09', '20-10', '20-11', '20-12', '21-01', '21-02', '21-03']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-74ca17e257c7> in <module>
#      24 plt.plot(month, cgv)
#      25 plt.xticks(color='white', fontsize =14)
# ---> 26 x.label(년-월)
#      27 plt.legend(['corona', 'netflix', 'cgv'])
#
# NameError: name 'x' is not defined
